# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# _`This notebook aids in summarizing Data Science Tools and Ecosystem.`_

# %% [markdown]
# `Some popular data science languages are:`
#
#     1) Python
#     2) R
#     3) Java
#     4) Scala
#     5) Ruby etc

# %% [markdown]
# `Some of the commonly used libraries used by Data Scientists include:`
#
#     1) Pandas
#     2) Tensorflow
#     3) Matplotlib
#     4) Seaborn

# %% [markdown]
# | Data Science Tools |
# |:---|
# Jupyter Notebooks
# R Studio
# Github

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
a = 5
b = 6
c = 9
# This a simple arithmetic expression to mutiply then add integers
d = a+b*c-1
d
# Out:
# 58

# %%
n = 540
# This function converts minutes to hours
def convertMtoH(time):
    return time/60
print(n,'minutes is',convertMtoH(n),'hrs')
# Out:
# 540 minutes is 9.0 hrs

# %% [markdown]
# **Objectives:**
# 1) List of Data Science tools
# 2) List of famous programming languages
# 3) Basic arithematic operations

# %% [markdown]
# ## Author
# Shabareesh Aryan
